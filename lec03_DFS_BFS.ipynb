# %% [markdown]
# <a href="https://colab.research.google.com/github/SangOh-Im/coding_test/blob/main/lec03_DFS_BFS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 원하는 데이터를 찾는 과정 (탐색)

# %%
# 스택구조(프링글스)
stack = []
stack.append(1)
stack.append(2)
stack.append(3)
stack.pop()
stack.append(4)

print(stack[::-1]) # 최상단부터 출력
print(stack)
# Out:
# [4, 2, 1]
# [1, 2, 4]

# %%
# 큐 자료구조 (터널)
from collections import deque

queue = deque()

queue.append(5)
queue.append(2)
queue.append(3)
queue.append(7)
queue.popleft()
queue.append(1)
queue.append(4)
queue.popleft()

print(queue)
queue.reverse()
print(queue)
# Out:
# deque([3, 7, 1, 4])
# deque([4, 1, 7, 3])

# %%
# 재귀함수
def recursive_function(i):
  if i == 100:
    return
  
  print(i,'번째 재귀함수를 호출합니다',i+1,'번째 재귀함수를 호출합니다')
  recursive_function(i+1)
  
  print(i,'번째 재귀함수를 종료합니다')
recursive_function(1)
# Out:
# 1 번째 재귀함수를 호출합니다 2 번째 재귀함수를 호출합니다
# 2 번째 재귀함수를 호출합니다 3 번째 재귀함수를 호출합니다
# 3 번째 재귀함수를 호출합니다 4 번째 재귀함수를 호출합니다
# 4 번째 재귀함수를 호출합니다 5 번째 재귀함수를 호출합니다
# 5 번째 재귀함수를 호출합니다 6 번째 재귀함수를 호출합니다
# 6 번째 재귀함수를 호출합니다 7 번째 재귀함수를 호출합니다
# 7 번째 재귀함수를 호출합니다 8 번째 재귀함수를 호출합니다
# 8 번째 재귀함수를 호출합니다 9 번째 재귀함수를 호출합니다
# 9 번째 재귀함수를 호출합니다 10 번째 재귀함수를 호출합니다
# 10 번째 재귀함수를 호출합니다 11 번째 재귀함수를 호출합니다
# 11 번째 재귀함수를 호출합니다 12 번째 재귀함수를 호출합니다
# 12 번째 재귀함수를 호출합니다 13 번째 재귀함수를 호출합니다
# 13 번째 재귀함수를 호출합니다 14 번째 재귀함수를 호출합니다
# 14 번째 재귀함수를 호출합니다 15 번째 재귀함수를 호출합니다
# 15 번째 재귀함수를 호출합니다 16 번째 재귀함수를 호출합니다
# 16 번째 재귀함수를 호출합니다 17 번째 재귀함수를 호출합니다
# 17 번째 재귀함수를 호출합니다 18 번째 재귀함수를 호출합니다
# 18 번째 재귀함수를 호출합니다 19 번째 재귀함수를 호출합니다
# 19 번째 재귀함수를 호출합니다 20 번째 재귀함수를 호출합니다
# 20 번째 재귀함수를 호출합니다 21 번째 재귀함수를 호출합니다
# 21 번째 재귀함수를 호출합니다 22 번째 재귀함수를 호출합니다
# 22 번째 재귀함수를 호출합니다 23 번째 재귀함수를 호출합니다
# 23 번째 재귀함수를 호출합니다 24 번째 재귀함수를 호출합니다
# 24 번째 재귀함수를 호출합니다 25 번째 재귀함수를 호출합니다
# 25 번째 재귀함수를 호출합니다 26 번째 재귀함수를 호출합니다
# 26 번째 재귀함수를 호출합니다 27 번째 재귀함수를 호출합니다
# ...

# %%
# 팩토리얼 구현 (재귀식으로 표현가능한 경우 반복문으로도 표현 가능)
def factorial_recursive(n):
  if n <= 1:
    return 1
  return n*factorial_recursive(n-1)
factorial_recursive(5)
# Out:
# 120

# %%
# 유클리드 호제법 (a,b의 최대공약수는 a,r의 최대공약수[r은 a를 b로 나눈 나머지])
def gcd(a,b):
  if a%b == 0:
    return b
  else:
    return gcd(b,a%b)

print(gcd(192,162))
# Out:
# 6

# %% [markdown]
# # DFS

# %%
# dfs 깊이 우선 탐색(스택 대신에 재귀함수 이용가능하다)
# DFS 메서드 정의
def dfs(graph, v, visited):
  # 현재 노드를 방문 처리
  visited[v] = True
  print(v,end = '')
  # 현재 노드와 연결된 다른 노드를 재귀적으로 방문
  for i in graph[v]:
    if not visited[i]:
      dfs(graph,i,visited)

graph = [
         [], # 0번 노드는 없다.
         [2,3,8], # 1번 노드에 연결된 노드는 2 3 8
         [1,7],
         [1,4,5],
         [3,5],
         [3,4],
         [7],
         [2,6,8],
         [1,7]
]

# 각 노드가 방문된 정보를 표현 (1차원 리스트)
visited = [False] * 9 # index 0은 사용 안한다.

# 정의된 DFS 함수 호출
dfs(graph,1,visited)
# Out:
# 12768345

# %% [markdown]
# # BFS

# %%
# bfs 너비 우선 탐색, 가까운 노드부터 우선적으로 탐색하는 알고리즘
# 큐 자료구조
from collections import deque

# BFS 함수 정의
def bfs(graph, start, visited):
    # 큐(Queue) 구현을 위해 deque 라이브러리 사용
    queue = deque([start])
    # 현재 노드를 방문 처리
    visited[start] = True
    # 큐가 빌 때까지 반복
    while queue:
        # 큐에서 하나의 원소를 뽑아 출력
        v = queue.popleft()
        print(v, end=' ')
        # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
        for i in graph[v]:
            if not visited[i]:
                queue.append(i)
                visited[i] = True

# 각 노드가 연결된 정보를 리스트 자료형으로 표현(2차원 리스트)
graph = [
  [],
  [2, 3, 8],
  [1, 7],
  [1, 4, 5],
  [3, 5],
  [3, 4],
  [7],
  [2, 6, 8],
  [1, 7]
]

# 각 노드가 방문된 정보를 리스트 자료형으로 표현(1차원 리스트)
visited = [False] * 9

# 정의된 BFS 함수 호출
bfs(graph, 1, visited)
# Out:
# 1 2 3 8 7 4 5 6

# %%
# 아이스크림 얼리기
# N, M을 공백을 기준으로 구분하여 입력 받기
n, m = map(int, input().split())

# 2차원 리스트의 맵 정보 입력 받기
graph = []
for i in range(n):
    graph.append(list(map(int, input())))

# DFS로 특정한 노드를 방문한 뒤에 연결된 모든 노드들도 방문
def dfs(x, y):
    # 주어진 범위를 벗어나는 경우에는 즉시 종료
    if x <= -1 or x >= n or y <= -1 or y >= m:
        return False
    # 현재 노드를 아직 방문하지 않았다면
    if graph[x][y] == 0:
        # 해당 노드 방문 처리
        graph[x][y] = 1
        # 상, 하, 좌, 우의 위치들도 모두 재귀적으로 호출
        dfs(x - 1, y)
        dfs(x, y - 1)
        dfs(x + 1, y)
        dfs(x, y + 1)
        return True
    return False

# 모든 노드(위치)에 대하여 음료수 채우기
result = 0
for i in range(n):
    for j in range(m):
        # 현재 위치에서 DFS 수행
        if dfs(i, j) == True:
            result += 1

print(result) # 정답 출력
# Out:
# 4 5
# 00110
# 00011
# 11111
# 00000
# 3

# %%
# 미로탈출
from collections import deque

# N, M을 공백을 기준으로 구분하여 입력 받기
n, m = map(int, input().split())
# 2차원 리스트의 맵 정보 입력 받기
graph = []
for i in range(n):
    graph.append(list(map(int, input())))

# 이동할 네 가지 방향 정의 (상, 하, 좌, 우)
dx = [-1, 1, 0, 0]
dy = [0, 0, -1, 1]

# BFS 소스코드 구현
def bfs(x, y):
    # 큐(Queue) 구현을 위해 deque 라이브러리 사용
    queue = deque()
    queue.append((x, y))
    # 큐가 빌 때까지 반복하기
    while queue:
        x, y = queue.popleft()
        # 현재 위치에서 4가지 방향으로의 위치 확인
        for i in range(4):
            nx = x + dx[i]
            ny = y + dy[i]
            # 미로 찾기 공간을 벗어난 경우 무시
            if nx < 0 or nx >= n or ny < 0 or ny >= m:
                continue
            # 벽인 경우 무시
            if graph[nx][ny] == 0:
                continue
            # 해당 노드를 처음 방문하는 경우에만 최단 거리 기록
            if graph[nx][ny] == 1:
                graph[nx][ny] = graph[x][y] + 1
                queue.append((nx, ny))
    # 가장 오른쪽 아래까지의 최단 거리 반환
    return graph[n - 1][m - 1]

# BFS를 수행한 결과 출력
print(bfs(0, 0))
# Out:
# 5 6
# 101010
# 111111
# 000001
# 111111
# 111111
# 10
